# %%
import pandas as pd

df1 = pd.read_csv('facility_visits.csv')
df2 = pd.read_csv('facility_visits[1].csv')

# %%
df2.head()
# Out:
#                                      id                             parent_id  \
# 0  bd1f88f0-a5ac-40ea-889f-7996faea2a49  08e447d5-a26a-4249-91a3-fb01cc8fcc4a
# 1  df1de357-0133-4912-87b2-25ed14221049  10d8d703-1cc2-426e-9c68-b4670e2cc487
# 2  aa1f5973-ed5c-446c-b305-3be925dcbf20  ec8b3b43-8a54-4f6d-a6f7-a78966ca5f18
# 3  77e5ef60-308f-4ede-b501-afa3104fa85f  0abd4cb2-cecb-4b8e-a3ad-af332f75a212
# 4  e2b7f030-d84d-4a7b-bcf8-a4562f0c2cdd  3f09ed7a-28a9-4d66-84a5-316e78806bd6
#
#    visit_date         track               vaccines_administered  age_years  \
# 0  2024-09-17  immunization           {Measles_1,YF,meningitis}          0
# 1  2024-09-17  immunization           {Measles_1,YF,meningitis}          0
# 2  2024-09-17  immunization                  {BCG,HepB_0,OPV_0}          0
# 3  2024-09-17  immunization  {Penta_1,PCV_1,OPV_1,Rota_1,IPV_1}          0
# 4  2024-09-17  immunization                  {BCG,HepB_0,OPV_0}          0
#
# ...

# %%
merged = df1.merge(df2,on='id',how='inner')
merged
# Out:
# Empty DataFrame
# Columns: [id, visit_date_x, track_x, vaccines_administered_x, age_years_x, age_months_x, age_weeks_x, gender_x, woman_or_child_x, health_center_id_x, health_center_name_x, lga_id_x, lga_name_x, parent_id, visit_date_y, track_y, vaccines_administered_y, age_years_y, age_months_y, age_weeks_y, gender_y, woman_or_child_y, health_center_id_y, health_center_name_y, lga_id_y, lga_name_y]
# Index: []
#
# [0 rows x 26 columns]

# %%
temp=df2['parent_id'].value_counts().sort_values(ascending=False)
# Out:
# parent_id
# ebf455dc-3c50-489d-8614-d8550386c3c0    20
# d77bcbbc-5694-4e96-8edb-ed0ebb857c48    19
# 139ba1e3-c79c-4d1f-b8a4-5dc4a33f7602    19
# e82052e0-d038-4fe6-8607-b56a1b77be36    18
# 274c8583-49ff-4693-8907-4bff616b12a6    18
#                                         ..
# 72995578-c067-4743-8059-fd56f168d32d     1
# f97eaa51-5c8b-4105-bb64-4aa9a4b98737     1
# cfa27b06-bc82-4ca6-92af-6ed702588be6     1
# 1455ec1a-c0f5-417b-8d51-5ad8198ea30d     1
# 944ceb53-5470-4182-a9b7-b1ee5e1b2824     1
# Name: count, Length: 37995, dtype: int64

# %%
df1['id'].value_counts().sort_values(ascending=False)
# Out:
# id
# 66d0bd61-8071-43f0-9c93-7a97e50f0a34    1
# 5d666d3a-c81b-4e7f-81a7-77ede4fa2de8    1
# 5bc781de-7407-4f35-9f06-895db648c767    1
# 6d3ebf2c-7d12-48a4-b5e9-35fe4d4775e5    1
# e3c913c8-c34e-48bf-af80-419b44aece91    1
#                                        ..
# 49212c47-149e-493f-8415-82320ac96f6f    1
# 033b792c-2cad-4ba8-a5bf-4939d4a32fe3    1
# ba61bd7b-ba2e-4282-a20e-bd898402a8e5    1
# 9de2924e-a447-4312-8023-3915739a4430    1
# 1b817739-134e-4c45-a3dc-c5475e5ce47d    1
# Name: count, Length: 82274, dtype: int64

# %%
pd.set_option('display.max_rows',100)

# %%
# Out:
# parent_id
# ebf455dc-3c50-489d-8614-d8550386c3c0    20
# d77bcbbc-5694-4e96-8edb-ed0ebb857c48    19
# 139ba1e3-c79c-4d1f-b8a4-5dc4a33f7602    19
# e82052e0-d038-4fe6-8607-b56a1b77be36    18
# 274c8583-49ff-4693-8907-4bff616b12a6    18
#                                         ..
# d96e422a-5424-44fe-bf5f-20e4977a71dd     4
# e072d578-a371-44fc-a0bc-274953f001d1     4
# 4e9c0616-0ef3-4a49-adcb-0ba2e86296cb     4
# 17804484-4474-4101-a6c2-1a629d696dfe     4
# 007af1ff-5a4d-4855-b195-3ebfd39d9a59     4
# Name: count, Length: 6000, dtype: int64
